# %% [markdown]
# ## Tarea 1 Módulo 5

# %% [markdown]
# 1. Graficar una red neuronal con $w_0$, $M$=3, $L_1$=4, $L_2$=2, $L_3$=2, $t \in R$

# %% [markdown]
# <img src="./Red_neuronal.GIF">

# %% [markdown]
# 2. Contar el número total de pesos $w^{(1)}$, $w^{(1)}$, $w^{(3)}$, $w^{(4)}$.

# %% [markdown]
# Formula para la obtención de la cantidad de pesos es $w = (x L_1) +  (L_1 L_2)+ (L_3 L_4)$
#
# $w = (3*4)+(4*2)+(2*2)+2*(1)$
#
# Fórmula para obtensióm de la cantidad de Sesgos  $w_0= L_1 + L_2+L^{(3)} +L^{(4)}$
#
# $w_0=4+2+2+1$

# %%
w = (3*4)+(4*2)+(2*2)+2*(1)
print("w =",w)
# Out:
# w = 26

# %%
w0=4+2+2+1
print("Sesgos w0 =",w0)
# Out:
# Sesgos w0 = 9

# %% [markdown]
# 3. Descomponer explícitamente $\hat{y}_n$ en términos de $w^{(1)}$

# %% [markdown]
# Desglose de los elementos:
#
# $\hat y = a^{(4)}$
#
# $a^{(4)} = f^{(4)}(w^{(4)}_{11}a^{(3)}_1 + w^{(4)}_{12}a^{(3)}_2 +w^{(4)}_{10}w^{(4)}_0) $
# ***
# $a^{(3)}_1 = f^{(3)}(w^{(3)}_{11} a^{(2)}_ 1 +  w^{(3)}_{12}a^{(2)}_2 +w^{(3)}_{10} w^{(3)}_0) $
#
# $a^{(3)}_2 = f^{(3)}(w^{(3)}_{21} a^{(2)}_ 1 +  w^{(3)}_{22}a^{(2)}_2 + w^{(3)}_{20}w^{(3)}_0) $
# ***
# $a^{(2)}_1 = f^{(2)}(w^{(2)}_{11}a^{(1)}_1 + w^{(2)}_{12}a^{(1)}_2 + w^{(2)}_{13}a^{(1)}_3 + w^{(2)}_{14}a^{(1)}_4 + w^{(2)}_{10}w^{(2)}_0)$
#
# $a^{(2)}_2 = f^{(2)}(w^{(2)}_{21}a^{(1)}_1 + w^{(2)}_{22}a^{(1)}_2 + w^{(2)}_{23}a^{(1)}_3 + w^{(2)}_{24}a^{(1)}_4 + w^{(2)}_{20}w^{(2)}_0)$
# ***
# $a^{(1)}_1 = f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0)$
#
# $a^{(1)}_2 = f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0)$
#
# $a^{(1)}_3 = f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0)$
#
# $a^{(1)}_4 = f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0)$
# ***
#
# Una vez planteados todos los elementos se sustituyen  $a^{(1)}_1$, $a^{(1)}_2$, $a^{(1)}_3$ y $a^{(1)}_4$ en $a^{(2)}_1$ y $a^{(2)}_2$:
#
#
# $a^{(2)}_1 = f^{(2)}(w^{(2)}_{11}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{12}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{13}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{14}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{10}w^{(2)}_0)$
#
# $a^{(2)}_2 = f^{(2)}(w^{(2)}_{21}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{22}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{23}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{24}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{20}w^{(2)}_0)$
#
#
# ***
#
# Ahora se sustituyen $a^{(2)}_1$ y $a^{(2)}_2$ en $a^{(3)}_1$ y $a^{(3)}_2$:
#
# $a^{(3)}_1 = f^{(3)}(w^{(3)}_{11}f^{(2)}(w^{(2)}_{11}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{12}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{13}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{14}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{10}w^{(2)}_0) +  w^{(3)}_{12}f^{(2)}(w^{(2)}_{21}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{22}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{23}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{24}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{20}w^{(2)}_0) +w^{(3)}_{10} w^{(3)}_0) $
#
# $a^{(3)}_2 = f^{(3)}(w^{(3)}_{21} f^{(2)}(w^{(2)}_{11}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{12}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{13}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{14}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{10}w^{(2)}_0) +  w^{(3)}_{22}f^{(2)}(w^{(2)}_{21}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{22}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{23}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{24}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{20}w^{(2)}_0) + w^{(3)}_{20}w^{(3)}_0) $
#
#
# ***
#
# Ahora se sustituyen $a^{(3)}_1$ y $a^{(3)}_2$ en $a^{(4)}$:
#
# $a^{(4)} = f^{(4)}(w^{(4)}_{11}f^{(3)}(w^{(3)}_{11}f^{(2)}(w^{(2)}_{11}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{12}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{13}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{14}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{10}w^{(2)}_0) +  w^{(3)}_{12}f^{(2)}(w^{(2)}_{21}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{22}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{23}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{24}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{20}w^{(2)}_0) +w^{(3)}_{10} w^{(3)}_0) + w^{(4)}_{12}f^{(3)}(w^{(3)}_{21} f^{(2)}(w^{(2)}_{11}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{12}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{13}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{14}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{10}w^{(2)}_0) +  w^{(3)}_{22}f^{(2)}(w^{(2)}_{21}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{22}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{23}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{24}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{20}w^{(2)}_0) + w^{(3)}_{20}w^{(3)}_0) +w^{(4)}_{10}w^{(4)}_0) $
#
#
# ***
#
# Para finalizar se sustituye $a^{(
# 4)}$ obetirndo la ecuación final de $\hat y$ en función de los pesos $w$:
#
#
# $\hat y = f^{(4)}(w^{(4)}_{11}f^{(3)}(w^{(3)}_{11}f^{(2)}(w^{(2)}_{11}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{12}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{13}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{14}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{10}w^{(2)}_0) +  w^{(3)}_{12}f^{(2)}(w^{(2)}_{21}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{22}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{23}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{24}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{20}w^{(2)}_0) +w^{(3)}_{10} w^{(3)}_0) + w^{(4)}_{12}f^{(3)}(w^{(3)}_{21} f^{(2)}(w^{(2)}_{11}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{12}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{13}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{14}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{10}w^{(2)}_0) +  w^{(3)}_{22}f^{(2)}(w^{(2)}_{21}f^{(1)}(w^{(1)}_{11}x_1+w^{(1)}_{12} x_2+w^{(1)}_{13}x_3+w^{(1)}_{10}w^{(1)}_0) + w^{(2)}_{22}f^{(1)}(w^{(1)}_{21}x_1+w^{(1)}_{22} x_2+w^{(1)}_{23}x_3+w^{(1)}_{20}w^{(1)}_0) + w^{(2)}_{23}f^{(1)}(w^{(1)}_{31}x_1+w^{(1)}_{32} x_2+w^{(1)}_{33}x_3+w^{(1)}_{30}w^{(1)}_0) + w^{(2)}_{24}f^{(1)}(w^{(1)}_{41}x_1+w^{(1)}_{42} x_2+w^{(1)}_{43}x_3+w^{(1)}_{40}w^{(1)}_0) + w^{(2)}_{20}w^{(2)}_0) + w^{(3)}_{20}w^{(3)}_0) +w^{(4)}_{10}w^{(4)}_0) $
